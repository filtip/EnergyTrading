# %%
import settings
import pandas as pd
import importlib
import strategy
import plots_statistics
importlib.reload(plots_statistics)
importlib.reload(strategy)
from plots_statistics import calculate_total_pnl
from strategy import run_multiple_contracts
from settings import load_project_data

# %%
data = load_project_data()
open_until = settings.open_until
close_until = settings.close_time_limit
contracts = settings.BEST_PREDICTORS.keys()
dict_thresholds = settings.BEST_PREDICTORS

# %%
#IN SAMPLE TRADES - MULTI ENTRY
prediction_path = "/Users/filipekrt/SF/Ekrt/sf_project/predictions_in_sample"
trades_in = run_multiple_contracts(data.data_in, data.bid_ask_in, contracts, dict_thresholds, open_until, close_until, prediction_path)
#trades_in.to_parquet(settings.ROOT / "sf_project" / "trades_in_sample.parquet")
# Out:
# Processing GAS_M_1...
# Processing GAS_M_2...
# Processing EM_M_1...
# /Users/filipekrt/SF/Ekrt/sf_project/strategy.py:275: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   prediction = pd.read_parquet(pred_file)
# Processing QY_2...
# /Users/filipekrt/SF/Ekrt/sf_project/strategy.py:275: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   prediction = pd.read_parquet(pred_file)
# Processing QY_3...
# ...

# %%
trades_in
# Out:
#       threshold contract        day trade_type                    t_open  \
# 0         0.075  GAS_M_1 2025-03-05      Short 2025-03-05 08:47:00+01:00
# 1         0.100  GAS_M_1 2025-03-07       Long 2025-03-07 08:44:00+01:00
# 2         0.050  GAS_M_1 2025-03-17       Long 2025-03-17 09:15:00+01:00
# 3         0.050  GAS_M_1 2025-03-18      Short 2025-03-18 09:40:00+01:00
# 4         0.075  GAS_M_1 2025-03-21      Short 2025-03-21 08:28:00+01:00
# ...         ...      ...        ...        ...                       ...
# 1366      0.350  IT_QY_1 2025-07-21       Long 2025-07-21 09:34:00+02:00
# 1367      0.350  IT_QY_1 2025-07-30       Long 2025-07-30 09:37:00+02:00
# 1368      0.525  IT_QY_1 2025-08-22      Short 2025-08-22 08:47:00+02:00
# 1369      0.700  IT_QY_1 2025-08-22      Short 2025-08-22 09:03:00+02:00
# 1370      0.350  IT_QY_1 2025-08-28      Short 2025-08-28 08:34:00+02:00
#
#                        t_close  entry_price  close_price  new_opened  \
# ...

# %%
#OUT-OF-SAMPLE TRADES - MULTI ENTRY
prediction_path = "/Users/filipekrt/SF/Ekrt/sf_project/predictions_out_of_sample"
trades_out = run_multiple_contracts(data.data_out, data.bid_ask_out, contracts, dict_thresholds, open_until, close_until, prediction_path)
#trades_out.to_parquet(settings.ROOT / "sf_project" / "trades_out_of_sample.parquet")
# Out:
# Processing GAS_M_1...
# Processing GAS_M_2...
# Processing EM_M_1...
# Processing QY_2...
# Processing QY_3...
# Processing QY_4...
# Processing QY_5...
# Processing Y_2...
# Processing M_2...
# Processing M_3...
# Processing M_4...
# Processing M_5...
# Processing IT_M_1...
# Processing IT_QY_1...

# %%
trades_out
# Out:
#      threshold contract        day trade_type                    t_open  \
# 0        0.050  GAS_M_1 2025-10-02      Short 2025-10-02 08:12:00+02:00
# 1        0.075  GAS_M_1 2025-10-06      Short 2025-10-06 09:30:00+02:00
# 2        0.050  GAS_M_1 2025-10-09       Long 2025-10-09 08:19:00+02:00
# 3        0.050  GAS_M_1 2025-10-10      Short 2025-10-10 08:07:00+02:00
# 4        0.050  GAS_M_1 2025-10-13      Short 2025-10-13 09:00:00+02:00
# ..         ...      ...        ...        ...                       ...
# 541      0.350   IT_M_1 2025-12-18      Short 2025-12-18 08:53:00+01:00
# 542      0.350  IT_QY_1 2025-11-21      Short 2025-11-21 09:01:00+01:00
# 543      0.525  IT_QY_1 2025-11-21      Short 2025-11-21 09:04:00+01:00
# 544      0.350  IT_QY_1 2025-12-15      Short 2025-12-15 09:26:00+01:00
# 545      0.350  IT_QY_1 2025-12-17       Long 2025-12-17 09:29:00+01:00
#
#                       t_close  entry_price  close_price  new_opened  \
# ...

# %%
calculate_total_pnl(trades_out)
# Out:
#                     PnL
# EM_M_1     11924.583238
# GAS_M_1     1493.649492
# GAS_M_2      -30.148574
# M_1            0.000000
# M_2        23317.305501
# M_3        10483.040429
# M_4         2322.218446
# M_5          -46.929680
# IT_M_1      5611.908512
# QY_1           0.000000
# QY_2       21577.571670
# QY_3       -5248.682337
# QY_4        3543.219681
# QY_5       -2982.150289
# QY_6           0.000000
# IT_QY_1     1751.664104
# Y_1            0.000000
# Y_2        19728.945819
# Total_PnL  93446.196011

# %%
calculate_total_pnl(trades_in)
# Out:
#                      PnL
# EM_M_1      19527.022144
# GAS_M_1     13474.607117
# GAS_M_2      9985.044044
# M_1             0.000000
# M_2         18462.924786
# M_3         -6040.999500
# M_4          8746.403273
# M_5          -713.466747
# IT_M_1      19277.330769
# QY_1            0.000000
# QY_2        76316.775505
# QY_3        52801.869008
# QY_4        38346.503389
# QY_5        30198.602144
# QY_6            0.000000
# IT_QY_1     49397.179145
# Y_1             0.000000
# Y_2        128394.064494
# Total_PnL  458173.859573

# %%
#SINGLE- ENTRY - IN SAMPLE
#Zde jen pro jednoduchost nastav threshold 0.1 pro všechny
dict = {}
for target_col in contracts:
    dict[target_col] = 0.2
prediction_path = "/Users/filipekrt/SF/Ekrt/sf_project/predictions_in_sample"
single_trades_in = run_multiple_contracts(data.data_in, data.bid_ask_in, contracts, dict, open_until, close_until, prediction_path)
# Out:
# Processing GAS_M_1...
# Processing GAS_M_2...
# Processing EM_M_1...
# /Users/filipekrt/SF/Ekrt/sf_project/strategy.py:258: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# Processing QY_2...
# /Users/filipekrt/SF/Ekrt/sf_project/strategy.py:258: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# Processing QY_3...
# ...
