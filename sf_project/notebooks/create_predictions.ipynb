# %%
import sf_project.settings as settings
import importlib
import sf_project.create_prediction as create_prediction
importlib.reload(create_prediction)
from sf_project.create_prediction import Specification, DataTransformation, TrainModel, Prediction, InputsBuilder
import pandas as pd
from pathlib import Path

# %%
#LOAD DATA
DATA_DIR = settings.ROOT / "sf_project" / "data"
data_in = pd.read_parquet( DATA_DIR / "prices_in_sample.parquet")
data_w_contract_id = pd.read_parquet(DATA_DIR / "prices_in_sample_w_contract_id.parquet")
data_out = pd.read_parquet(DATA_DIR / "prices_out_of_sample.parquet")
data_w_contract_id_out = pd.read_parquet(DATA_DIR / "prices_out_of_sample_w_contract_id.parquet")

# %%
#IN SAMPLE PREDICTIONS
months = ["2025-03", "2025-04", "2025-05", "2025-06", "2025-07", "2025-08", "2025-09"]

for target_col in settings.BEST_PREDICTORS.keys():
    preds = []
    predictor_cols = settings.BEST_PREDICTORS[target_col]["predictor_cols"]

    spec = Specification(target_col=target_col,predictor_cols=predictor_cols)
    data_trans = DataTransformation(spec=spec)
    trainer = TrainModel(spec = spec, data_transformation= data_trans)
    inputs = InputsBuilder(spec = spec)
    predictor = Prediction(trainer = trainer, inputs = inputs)

    for prediction_month in months:
        trainer.fit_on_scenario(data=data_in, prediction_month=prediction_month)
        prediction = predictor.predict_whole_month(data_in, data_w_contract_id, prediction_month)
        preds.append(prediction)

    all_predictions = pd.concat(preds).sort_index()
    path_save = Path(DATA_DIR / "predictions" / "predictions_in_sample" )
    #all_predictions.to_parquet(f"{path_save}/{target_col}_predictions.parquet")
# Out:
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-04-02 08:39:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-05-02 08:43:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-06-02 08:37:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-07-01 08:19:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-08-01 08:20:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-09-01 08:16:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-04-02 08:39:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-05-02 08:43:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-06-02 08:37:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-07-01 08:19:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-08-01 08:20:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-09-01 08:16:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day EM_M_1, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day QY_2, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day QY_3, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day QY_4, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day QY_5, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day Y_2, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_2, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_3, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_4, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-04-02 08:39:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-05-02 08:36:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-06-02 08:37:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-07-01 08:19:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-08-01 08:20:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-09-01 08:22:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-04-02 08:39:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-05-02 08:43:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-06-02 08:37:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-07-01 08:19:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-08-01 08:20:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-09-01 08:22:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_QY_1, 2025-03-03 08:12:00+01:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_QY_1, 2025-04-02 08:39:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_QY_1, 2025-07-01 08:19:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()

# %%
#OUT OF SAMPLE PREDICTIONS
data_all = pd.concat([data_in, data_out], axis = 0).sort_index()
data_all_wcid = pd.concat([data_w_contract_id, data_w_contract_id_out], axis = 0).sort_index()

months = ["2025-10", "2025-11", "2025-12"]

for target_col in settings.BEST_PREDICTORS.keys():
    preds = []
    predictor_cols = settings.BEST_PREDICTORS[target_col]["predictor_cols"]

    spec = Specification(target_col=target_col,predictor_cols=predictor_cols)
    data_trans = DataTransformation(spec=spec)
    trainer = TrainModel(spec = spec, data_transformation= data_trans)
    inputs = InputsBuilder(spec = spec)
    predictor = Prediction(trainer = trainer, inputs = inputs)

    for prediction_month in months:
        trainer.fit_on_scenario_out_of_sample(data_in = data_in, data_out = data_out, prediction_month=prediction_month)
        prediction = predictor.predict_whole_month(data_all, data_all_wcid, prediction_month)
        preds.append(prediction)

    all_predictions = pd.concat(preds).sort_index()
    path_save = Path(DATA_DIR / "predictions" / "predictions_out_of_sample" )
    #all_predictions.to_parquet(f"{path_save}/{target_col}_predictions.parquet")
# Out:
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_1, 2025-10-01 08:40:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for GAS_M_1 in month 2025-11
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for GAS_M_1 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day GAS_M_2, 2025-10-01 08:40:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for GAS_M_2 in month 2025-11
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for GAS_M_2 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for EM_M_1 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for QY_4 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for QY_5 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for Y_2 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for M_2 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for M_3 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for M_4 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day M_5, 2025-10-01 08:40:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for M_5 in month 2025-11
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for M_5 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_M_1, 2025-10-01 08:40:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for IT_M_1 in month 2025-11
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for IT_M_1 in month 2025-12
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for first day IT_QY_1, 2025-10-01 08:40:00+02:00
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:174: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   periods = X.index.to_period("M")
# /Users/filipekrt/PycharmProjects/EnergyTrading/sf_project/create_prediction.py:216: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   training_months = y_train.index.to_period("M").unique()
# No prediction for IT_QY_1 in month 2025-12
